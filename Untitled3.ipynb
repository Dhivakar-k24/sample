# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhivakar-k24/sample/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-09a9ef6a-30d7-47b9-8de2-9a29e71e117e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09a9ef6a-30d7-47b9-8de2-9a29e71e117e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data2=pd.read_excel("projectdataset.xlsx")

# %%
df=pd.DataFrame(data2)

# %%
df
# Out:
#           FILENAME                                 URL  URLLength  \
# 0              NaN    https://www.southbankmosaics.com       31.0
# 1        31372.txt            https://www.uni-mainz.de       23.0
# 2       597387.txt      https://www.voicefmradio.co.uk       29.0
# 3       554095.txt         https://www.sfnmjournal.com       26.0
# 4       151578.txt  https://www.rewildingargentina.org       33.0
# ...            ...                                 ...        ...
# 6180   mw65555.txt         http://www.dijiu.welco.live       26.0
# 6181    556631.txt        https://www.nvd.uscourts.gov       27.0
# 6182  mw143410.txt        http://www.suriagrofresh.com       28.0
# 6183    844854.txt       https://www.khalifaqattan.com       28.0
# 6184   7532090.txt     https://url.dscdut.com/mail2022       30.0
#
#                           Domain  DomainLength  IsDomainIP   TLD  \
# 0       www.southbankmosaics.com          24.0         0.0   com
# ...

# %%
df.isnull().sum()
# Out:
# FILENAME                      2
# URL                           1
# URLLength                     1
# Domain                        4
# DomainLength                  4
# IsDomainIP                    3
# TLD                           5
# URLSimilarityIndex            6
# CharContinuationRate          8
# TLDLegitimateProb             8
# URLCharProb                   8
# TLDLength                     2
# NoOfSubDomain                 8
# HasObfuscation                5
# NoOfObfuscatedChar            2
# ObfuscationRatio              3
# NoOfLettersInURL              4
# LetterRatioInURL              3
# NoOfDegitsInURL               1
# DegitRatioInURL               3
# NoOfEqualsInURL               3
# NoOfQMarkInURL                1
# NoOfAmpersandInURL            1
# NoOfOtherSpecialCharsInURL    1
# SpacialCharRatioInURL         1
# IsHTTPS                       1
# LineOfCode                    1
# LargestLineLength             1
# HasTitle                      1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# FILENAME                      0
# URL                           0
# URLLength                     0
# Domain                        0
# DomainLength                  0
# IsDomainIP                    0
# TLD                           0
# URLSimilarityIndex            0
# CharContinuationRate          0
# TLDLegitimateProb             0
# URLCharProb                   0
# TLDLength                     0
# NoOfSubDomain                 0
# HasObfuscation                0
# NoOfObfuscatedChar            0
# ObfuscationRatio              0
# NoOfLettersInURL              0
# LetterRatioInURL              0
# NoOfDegitsInURL               0
# DegitRatioInURL               0
# NoOfEqualsInURL               0
# NoOfQMarkInURL                0
# NoOfAmpersandInURL            0
# NoOfOtherSpecialCharsInURL    0
# SpacialCharRatioInURL         0
# IsHTTPS                       0
# LineOfCode                    0
# LargestLineLength             0
# HasTitle                      0
# ...

# %%
df.to_csv("updated.csv")

# %%
files.download("updated.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df["URLLength"],labels=df["FILENAME"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcd4ef626c0>,
# ...
# ...
#   Text(0.8050163486656625, 0.7496323621489436, '8054126.txt'),
#   Text(0.8041870583681767, 0.7505219351578866, '27914.txt'),
#   Text(0.8036047748034205, 0.7511453693614466, '496305.txt'),
#   Text(0.8030467420007723, 0.7517419305599131, 'mw77034.txt'),
#   Text(0.8020039320070378, 0.7528543637684856, 'oph07736.txt'),
#   Text(0.8009222799542278, 0.7540049744351306, '161873.txt'),
#   Text(0.8002251992058671, 0.7547447452986544, '412733.txt'),
#   Text(0.7995647643516129, 0.7554443643362163, '132134.txt'),
#   Text(0.7989911025694669, 0.756051068390772, '164422.txt'),
#   Text(0.7984294730967259, 0.7566441544679275, '37988.txt'),
#   Text(0.7975424042831177, 0.7575791136048461, '7969961.txt'),
#   Text(0.7965540915492143, 0.7586182038655583, '8027430.txt'),
#   Text(0.7958778239800978, 0.7593276560857669, '760419.txt'),
#   Text(0.7953638564950987, 0.7598659985689874, '802433.txt'),
# ...

# %%
plt.show()

# %%
plt.scatter(df["URLLength"],df["FILENAME"],color="blue")
